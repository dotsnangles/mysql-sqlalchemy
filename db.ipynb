# %% [markdown]
# [Introduction to SQLAlchemy at PyCon 2013](https://www.youtube.com/watch?v=woKYyhLCcnU&t=175s)

# %% [markdown]
# ### Engine / Connection / Transaction

# %%
# !conda install -c conda-forge mysql-connector-python
# !conda install sqlalchemy flask
# !sudo apt install mysql-server
# !sudo service mysql start
# !sudo service mysql status
# !sudo mysql -u root -p

# %%
# CREATE USER 'jake'@'localhost' IDENTIFIED BY '0000';
# GRANT ALL ON *.* TO 'jake'@'localhost' WITH GRANT OPTION;
# CREATE DATABASE test;

# %%
# config.py
db = {
    'user'     : 'jake',		# 1)
    'password' : '0000',		# 2)
    'host'     : 'localhost',	# 3)
    'port'     : 3306,			# 4)
    'database' : 'mysql'		# 5)
}

DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}/{db['database']}?charset=utf8"
# DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}?charset=utf8"

# %%
from sqlalchemy import create_engine, text

# %%
engine = create_engine(DB_URL, encoding = 'utf-8', max_overflow = 0)

# %%
engine.table_names()
# Out:
# /tmp/ipykernel_2102/4162273999.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['columns_priv',
#  'component',
#  'db',
#  'default_roles',
#  'engine_cost',
#  'func',
#  'general_log',
#  'global_grants',
#  'gtid_executed',
#  'help_category',
#  'help_keyword',
#  'help_relation',
#  'help_topic',
#  'innodb_index_stats',
#  'innodb_table_stats',
#  'password_history',
#  'plugin',
#  'procs_priv',
#  'proxies_priv',
#  'replication_asynchronous_connection_failover',
#  'replication_asynchronous_connection_failover_managed',
#  'replication_group_configuration_version',
#  'replication_group_member_actions',
#  'role_edges',
#  'server_cost',
#  'servers',
#  'slave_master_info',
#  'slave_relay_log_info',
#  'slave_worker_info',
#  'slow_log',
#  'tables_priv',
#  'time_zone',
#  'time_zone_leap_second',
#  'time_zone_name',
#  'time_zone_transition',
#  'time_zone_transition_type',
#  'user']

# %%
engine
# Out:
# Engine(mysql+mysqlconnector://jake:***@localhost:3306/mysql?charset=utf8)

# %%
result = engine.execute(
    'select User from user'
)

rows = result.fetchall()

print(rows)
type(rows)
# Out:
# [('debian-sys-maint',), ('jake',), ('mysql.infoschema',), ('mysql.session',), ('mysql.sys',), ('root',)]
# list

# %%
result = engine.execute(
    'select User from user'
)

row = result.fetchone()

print(row)
type(row)
# Out:
# ('debian-sys-maint',)
# sqlalchemy.engine.row.LegacyRow

# %%
result = engine.execute(
    'select User from user'
)

rows = result.fetchmany(3)

print(rows)
type(rows)
# Out:
# [('debian-sys-maint',), ('jake',), ('mysql.infoschema',)]
# list

# %%
result = engine.execute(
    'select * from user'
)

rows = result.fetchall()

print(rows)
type(rows)
# Out:
# [('localhost', 'debian-sys-maint', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$%WYr#\t\x04Kfg\x02~o\x15b\x03\x1drTbqkJg/Xc7kqlAiqoMLmZpBV0jCzAD/fJS8BBr957hrxA', 'N', datetime.datetime(2022, 7, 19, 14, 2, 37), None, 'N', 'Y', 'Y', None, None, None, None), ('localhost', 'jake', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b"$A$005$7\x10p7mT\x1b>#nv1r\nZdx'baLwOOUD72cOcbEQQEGYd9swugBQZixnLCnzM1j07wA39", 'N', datetime.datetime(2022, 7, 19, 17, 4, 21), None, 'N', 'Y', 'Y', None, None, None, None), ('localhost', 'mysql.infoschema', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None), ('localhost', 'mysql.session', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None), ('localhost', 'mysql.sys', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None), ('localhost', 'root', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'auth_socket', b'', 'N', datetime.datetime(2022, 7, 19, 14, 2, 35), None, 'N', 'Y', 'Y', None, None, None, None)]
# list

# %%
print(result.keys())
type(result)
# Out:
# RMKeyView(['Host', 'User', 'Select_priv', 'Insert_priv', 'Update_priv', 'Delete_priv', 'Create_priv', 'Drop_priv', 'Reload_priv', 'Shutdown_priv', 'Process_priv', 'File_priv', 'Grant_priv', 'References_priv', 'Index_priv', 'Alter_priv', 'Show_db_priv', 'Super_priv', 'Create_tmp_table_priv', 'Lock_tables_priv', 'Execute_priv', 'Repl_slave_priv', 'Repl_client_priv', 'Create_view_priv', 'Show_view_priv', 'Create_routine_priv', 'Alter_routine_priv', 'Create_user_priv', 'Event_priv', 'Trigger_priv', 'Create_tablespace_priv', 'ssl_type', 'ssl_cipher', 'x509_issuer', 'x509_subject', 'max_questions', 'max_updates', 'max_connections', 'max_user_connections', 'plugin', 'authentication_string', 'password_expired', 'password_last_changed', 'password_lifetime', 'account_locked', 'Create_role_priv', 'Drop_role_priv', 'Password_reuse_history', 'Password_reuse_time', 'Password_require_current', 'User_attributes'])
# sqlalchemy.engine.cursor.LegacyCursorResult

# %%
result.fetchone()

# %%
conn = engine.connect()

# %%
result1 = conn.execute(
    'select * from user'
)

# %%
result1.fetchall()
# Out:
# [('localhost', 'debian-sys-maint', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$%WYr#\t\x04Kfg\x02~o\x15b\x03\x1drTbqkJg/Xc7kqlAiqoMLmZpBV0jCzAD/fJS8BBr957hrxA', 'N', datetime.datetime(2022, 7, 19, 14, 2, 37), None, 'N', 'Y', 'Y', None, None, None, None),
#  ('localhost', 'jake', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b"$A$005$7\x10p7mT\x1b>#nv1r\nZdx'baLwOOUD72cOcbEQQEGYd9swugBQZixnLCnzM1j07wA39", 'N', datetime.datetime(2022, 7, 19, 17, 4, 21), None, 'N', 'Y', 'Y', None, None, None, None),
#  ('localhost', 'mysql.infoschema', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None),
#  ('localhost', 'mysql.session', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None),
#  ('localhost', 'mysql.sys', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', '', b'', b'', b'', 0, 0, 0, 0, 'caching_sha2_password', b'$A$005$THISISACOMBINATIONOFINVALIDSALTANDPASSWORDTHATMUSTNEVERBRBEUSED', 'N', datetime.datetime(2022, 7, 19, 14, 2, 36), None, 'Y', 'N', 'N', None, None, None, None),
#  ('localhost', 'root', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', '', b'', b'', b'', 0, 0, 0, 0, 'auth_socket', b'', 'N', datetime.datetime(2022, 7, 19, 14, 2, 35), None, 'N', 'Y', 'Y', None, None, None, None)]

# %%
result2 = conn.execute(
    'select User from user'
)

# %%
result2.fetchall()
# Out:
# [('debian-sys-maint',),
#  ('jake',),
#  ('mysql.infoschema',),
#  ('mysql.session',),
#  ('mysql.sys',),
#  ('root',)]

# %%
conn = engine.connect()
trans = conn.begin()
conn.execute(
    'select User from user'
).fetchall()
trans.commit()
conn.close()

# %%
with engine.begin() as conn:
    result1 = conn.execute(
        'select User from user'
    ).fetchall()
    result2 = conn.execute(
        'select User from user where User = "jake"'
    ).fetchall()
    print(result1)
    print(result2)
# Out:
# [('debian-sys-maint',), ('jake',), ('mysql.infoschema',), ('mysql.session',), ('mysql.sys',), ('root',)]
# [('jake',)]

# %%
conn = engine.connect()
conn.execute(
    'select User from user'
).fetchall()
# Out:
# [('debian-sys-maint',),
#  ('jake',),
#  ('mysql.infoschema',),
#  ('mysql.session',),
#  ('mysql.sys',),
#  ('root',)]

# %% [markdown]
# ### Table / Metadata / Reflection / DDL

# %%
# config.py
db = {
    'user'     : 'jake',		# 1)
    'password' : '0000',		# 2)
    'host'     : 'localhost',	# 3)
    'port'     : 3306,			# 4)
    'database' : 'test'		# 5)
}

DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}/{db['database']}?charset=utf8"
# DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}?charset=utf8"

# %%
from sqlalchemy import create_engine, text

# %%
engine = create_engine(DB_URL, encoding = 'utf-8', max_overflow = 0)

# %%
from sqlalchemy import MetaData
from sqlalchemy import Table, Column
from sqlalchemy import Integer, String

metadata = MetaData()

user_table = Table(
    'user', metadata,
    Column('id', Integer, primary_key=True),
    Column('name', String(36)),
    Column('fullname', String(64)),
)

# %%
# user_table.name
# user_table.columns.keys()
# name_col = user_table.columns.name
# id_col = user_table.columns.id
# fullname_col = user_table.columns.fullname

# %%
# name_col.name
# name_col.type
# name_col.table

# %%
# metadata.create_all(engine)

# %%
from sqlalchemy import String, Numeric, DateTime, Enum

fancy_table = Table(
    'fancy', metadata,
    Column('key', String(50), primary_key=True),
    Column('timestamp', DateTime),
    Column('amount', Numeric(10,2)),
    Column('type', Enum('a','b','c')),
)

# %%
# fancy_table.create(engine)

# %%
from sqlalchemy import ForeignKey

addresses_table = Table(
    'address', metadata,
    Column('id', Integer, primary_key=True),
    Column('email_addresse', String(100), nullable=False),
    Column('user_id', Integer, ForeignKey('user.id')),
)

# %%
# addresses_table.create(engine)

# %%
from sqlalchemy import Unicode, UnicodeText, DateTime
from sqlalchemy import ForeignKeyConstraint

story_table = Table(
    'story', metadata,
    Column('story_id', Integer, primary_key=True),
    Column('version_id', Integer, primary_key=True),
    Column('headline', Unicode(100), nullable=False),
    Column('body', UnicodeText),
)

published_table = Table(
    'published', metadata,
    Column('pub_id', Integer, primary_key=True),
    Column('pub_timestamp', DateTime, nullable=False),
    Column('story_id', Integer),
    Column('version_id', Integer),
    ForeignKeyConstraint(
        ['story_id', 'version_id'],
        ['story.story_id', 'story.version_id'],
    ),
)

# %%
# story_table.create(engine)
# published_table.create(engine)

# %%
# engine.execute(
#     'describe published'
# ).fetchall()

# %%
from sqlalchemy import Integer, String, DateTime

network_table = Table(
    'network', metadata,
    Column('network_id', Integer, primary_key=True),
    Column('name', String(100), nullable=False),
    Column('created_at', DateTime, nullable=False),
    Column('owner_id', Integer, ForeignKey('user.id')),
)

# %%
metadata.create_all(engine)
# metadata.drop_all(engine)

# %% [markdown]
# #### Reflection

# %%
metadata2 = MetaData()
user_reflected = Table(
    'user',
    metadata2,
    autoload=True,
    autoload_with=engine
)
user_reflected
# Out:
# Table('user', MetaData(), Column('id', INTEGER(), table=<user>, primary_key=True, nullable=False), Column('name', VARCHAR(length=36), table=<user>), Column('fullname', VARCHAR(length=64), table=<user>), schema=None)

# %%
from sqlalchemy import inspect

inspector = inspect(engine)

# %%
inspector

# %%
inspector.get_table_names()
# Out:
# ['address', 'fancy', 'network', 'published', 'story', 'user']

# %%
inspector.get_columns('address')
# Out:
# [{'name': 'id',
#   'type': INTEGER(),
#   'default': None,
#   'comment': None,
#   'nullable': False,
#   'autoincrement': True},
#  {'name': 'email_addresse',
#   'type': VARCHAR(length=100),
#   'default': None,
#   'comment': None,
#   'nullable': False},
#  {'name': 'user_id',
#   'type': INTEGER(),
#   'default': None,
#   'comment': None,
#   'nullable': True,
#   'autoincrement': False}]

# %%
inspector.get_foreign_keys('address')
# Out:
# [{'name': 'address_ibfk_1',
#   'constrained_columns': ['user_id'],
#   'referred_schema': None,
#   'referred_table': 'user',
#   'referred_columns': ['id'],
#   'options': {}}]

# %%
for tname in inspector.get_table_names():
    for column in inspector.get_columns(tname):
        if column['name'] == 'story_id':
            print(tname)
# Out:
# published
# story

# %% [markdown]
# ### SQL Expressions

# %%
user_table.columns.name == 'ed'

# %%
x = user_table.columns.name == 'ed'
x

# %%
x == 'jack'

# %%
type(x == 'jack')
type(x == 'jack').__mro__
# Out:
# (sqlalchemy.sql.elements.BinaryExpression,
#  sqlalchemy.sql.elements.ColumnElement,
#  sqlalchemy.sql.roles.ColumnArgumentOrKeyRole,
#  sqlalchemy.sql.roles.ColumnArgumentRole,
#  sqlalchemy.sql.roles.StatementOptionRole,
#  sqlalchemy.sql.roles.WhereHavingRole,
#  sqlalchemy.sql.roles.OnClauseRole,
#  sqlalchemy.sql.roles.BinaryElementRole,
#  sqlalchemy.sql.roles.ExpressionElementRole,
#  sqlalchemy.sql.roles.OrderByRole,
#  sqlalchemy.sql.roles.ColumnsClauseRole,
#  sqlalchemy.sql.roles.AllowsLambdaRole,
#  sqlalchemy.sql.roles.ByOfRole,
#  sqlalchemy.sql.roles.UsesInspection,
#  sqlalchemy.sql.roles.ColumnListRole,
#  sqlalchemy.sql.roles.LimitOffsetRole,
#  sqlalchemy.sql.roles.DMLColumnRole,
#  sqlalchemy.sql.roles.DDLConstraintColumnRole,
#  sqlalchemy.sql.roles.DDLExpressionRole,
#  sqlalchemy.sql.roles.StructuralRole,
#  sqlalchemy.sql.operators.ColumnOperators,
#  sqlalchemy.sql.operators.Operators,
#  sqlalchemy.sql.elements.ClauseElement,
#  sqlalchemy.sql.roles.SQLRole,
#  sqlalchemy.sql.annotation.SupportsWrappingAnnotations,
#  sqlalchemy.sql.annotation.SupportsAnnotations,
#  sqlalchemy.sql.traversals.MemoizedHasCacheKey,
#  sqlalchemy.sql.traversals.HasCacheKey,
#  sqlalchemy.util.langhelpers.HasMemoized,
#  sqlalchemy.sql.traversals.HasCopyInternals,
#  sqlalchemy.sql.visitors.Traversible,
#  object)

# %%
str(x)
# Out:
# '"user".name = :name_1'

# %%
print(
    (user_table.columns.name == 'ed') | (user_table.columns.name == 'jack')
)
# Out:
# "user".name = :name_1 OR "user".name = :name_2

# %%
from sqlalchemy import and_, or_

print(
    and_(
        user_table.columns.name == 'ed',
        or_(
            user_table.columns.name == 'ed',
            user_table.columns.name == 'jack'
        )
    )
)
# Out:
# "user".name = :name_1 AND ("user".name = :name_2 OR "user".name = :name_3)

# %%
print(user_table.c.id > 5)
# Out:
# "user".id > :id_1

# %%
print(user_table.c.fullname == None)
print(user_table.c.fullname != None)
print(user_table.c.fullname.is_(None))
# Out:
# "user".fullname IS NULL
# "user".fullname IS NOT NULL
# "user".fullname IS NULL

# %%
# Numeric Addition
print(user_table.c.id + 5)
# Out:
# "user".id + :id_1

# %%
# String Concat
print(user_table.c.fullname + 'some name')
# Out:
# "user".fullname || :fullname_1

# %%
from sqlalchemy.dialects import mysql, postgresql

expression = user_table.c.name == 'ed'

print(
    expression.compile(dialect=mysql.dialect())
    )
print(
    expression.compile(dialect=postgresql.dialect())
    )
# Out:
# user.name = %s
# "user".name = %(name_1)s

# %%
compile = expression.compile()
print(compile.params)
expression.compile().params
# Out:
# {'name_1': 'ed'}
# {'name_1': 'ed'}

# %%
expression.left
# Out:
# Column('name', String(length=36), table=<user>)

# %%
expression.right
# Out:
# BindParameter('%(140323298039008 name)s', 'ed', type_=String(length=36))

# %%
engine.execute(
    user_table.select().where(user_table.c.name == 'ed')
)

# %% [markdown]
# ### Object Relational Mapping

# %%
# config.py
db = {
    'user'     : 'jake',		# 1)
    'password' : '0000',		# 2)
    'host'     : 'localhost',	# 3)
    'port'     : 3306,			# 4)
    'database' : 'test'		# 5)
}

DB_URL = f"mysql+mysqlconnector://jake:0000@localhost:3306/test"
# DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}/{db['database']}?charset=utf8"
# DB_URL = f"mysql+mysqlconnector://{db['user']}:{db['password']}@{db['host']}:{db['port']}?charset=utf8"

# %%
from sqlalchemy import create_engine

engine = create_engine(DB_URL)
# engine = create_engine(DB_URL, encoding = 'utf-8', max_overflow = 0)

# %%
from sqlalchemy.orm import declarative_base

Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String

class User(Base):
    __tablename__ = 'users'

    id = Column(Integer, primary_key=True)
    name = Column(String(30))
    fullname = Column(String(30))
    nickname = Column(String(30))

    def __repr__(self):
        return f'<User(name={self.name}, fullname={self.fullname}, nickname={self.nickname})>'

# %%
User.__table__
# Out:
# Table('users', MetaData(), Column('id', Integer(), table=<users>, primary_key=True, nullable=False), Column('name', String(length=30), table=<users>), Column('fullname', String(length=30), table=<users>), Column('nickname', String(length=30), table=<users>), schema=None)

# %%
Base.metadata.create_all(engine)

# %%
ed_user = User(name='ed', fullname='Ed Jones', nickname='edsnickname')
print(ed_user.name)
print(ed_user.fullname)
print(ed_user.nickname)
print(str(ed_user.id))
# Out:
# ed
# Ed Jones
# edsnickname
# None

# %%
jake_user = User(name='jake', fullname='Jake Park', nickname='sorry')
print(jake_user.name)
print(jake_user.fullname)
print(jake_user.nickname)
print(str(jake_user.id))
print(jake_user)
# Out:
# jake
# Jake Park
# sorry
# None
# <User(name=jake, fullname=Jake Park, nickname=sorry)>

# %%
from sqlalchemy.orm import sessionmaker

Session = sessionmaker(bind=engine)

# %%
session = Session()

# %%
session.add(ed_user)
session.add(jake_user)

# %%
our_user = session.query(User).filter_by(name='ed').first()
our_user
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>

# %%
print(ed_user is our_user)
print(ed_user == our_user)
# Out:
# False
# False

# %%
session.add_all([
    User(name='wendy', fullname='Wendy Williams', nickname='windy'),
    User(name='mary', fullname='Mary Contrary', nickname='mary'),
    User(name='fred', fullname='Fred Flinstone', nickname='freddy'),
])

# %%
ed_user.nickname = 'eddie'
session.dirty
# Out:
# IdentitySet([<User(name=ed, fullname=Ed Jones, nickname=eddie)>])

# %%
session.new
# Out:
# IdentitySet([<User(name=wendy, fullname=Wendy Williams, nickname=windy)>, <User(name=mary, fullname=Mary Contrary, nickname=mary)>, <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>])

# %%
session.commit()

# %%
ed_user.id
# Out:
# 19

# %%
ed_user.name = 'Edwardo'

# %%
fake_user = User(
    name='fakeuser',
    fullname='Invalid',
    nickname='12345'
)
session.add(fake_user)

# %%
session.query(User).filter(User.name.in_(['Edwardo', 'fakeuser'])).all()
# Out:
# [<User(name=Edwardo, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=fakeuser, fullname=Invalid, nickname=12345)>]

# %%
session.rollback()

# %%
ed_user.name
# Out:
# 'ed'

# %%
fake_user in session
# Out:
# False

# %%
session.query(User).filter(User.name.in_(['ed', 'fakeuseer'])).all()
# Out:
# [<User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>]

# %%
for instance in session.query(User).order_by(User.id):
    print(instance.name, instance.fullname)
# Out:
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone

# %%
for name, fullname in session.query(User.name, User.fullname):
    print(name, fullname)
# Out:
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone
# ed Ed Jones
# jake Jake Park
# wendy Wendy Williams
# mary Mary Contrary
# fred Fred Flinstone

# %%
for row in session.query(User, User.name).all():
    print(row.User, row.name)
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> ed
# <User(name=jake, fullname=Jake Park, nickname=sorry)> jake
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> wendy
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> mary
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> fred
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> ed
# <User(name=jake, fullname=Jake Park, nickname=sorry)> jake
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> wendy
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> mary
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> fred
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> ed
# <User(name=jake, fullname=Jake Park, nickname=sorry)> jake
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> wendy
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> mary
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> fred
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> ed
# <User(name=jake, fullname=Jake Park, nickname=sorry)> jake
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> wendy
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> mary
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> fred

# %%
for row in session.query(User.name.label('name_label')).all():
    print(row.name_label)
# Out:
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred

# %%
User.name.label('name_label')

# %%
from sqlalchemy.orm import aliased

user_alias = aliased(User, name='user_alias')

for row in session.query(user_alias, user_alias.name).all():
    print(row.user_alias)
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>

# %%
for u in session.query(User).order_by(User.id)[0:3]:
    print(u)
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>

# %%
for name in session.query(User.name).\
    filter_by(fullname='Ed Jones'):
    print(name)
# Out:
# ('ed',)
# ('ed',)
# ('ed',)
# ('ed',)

# %%
for name in session.query(User.name).filter(User.fullname=='Ed Jones'):
    print(name)
# Out:
# ('ed',)
# ('ed',)
# ('ed',)
# ('ed',)

# %%
for user in session.query(User).filter(User.name=='ed').filter(User.fullname=='Ed Jones'):
    print(user.fullname)
# Out:
# Ed Jones
# Ed Jones
# Ed Jones
# Ed Jones

# %%
# query.filter(User.name == 'ed')
# query.filter(User.name != 'ed')
# query.filter(User.name.like('%ed%'))
# query.filter(User.name.ilike('%ed%'))

# %%
# query.filter(User.name.in_(['ed', 'wendy', 'jack']))

# # works with query objects too:
# query.filter(User.name.in_(
#     session.query(User.name).filter(User.name.like('%ed%'))
# ))

# # use tuple_() for composite (multi-column) queries
# from sqlalchemy import tuple_
# query.filter(
#     tuple_(User.name, User.nickname).\
#     in_([('ed', 'edsnickname'), ('wendy', 'windy')])
# )

# %%
# query.filter(~User.name.in_(['ed', 'wendy', 'jack']))

# %%
# query.filter(User.name == None)

# # alternatively, if pep8/linters are a concern
# query.filter(User.name.is_(None))

# %%
# query.filter(User.name != None)

# # alternatively, if pep8/linters are a concern
# query.filter(User.name.is_not(None))

# %%
# # use and_()
# from sqlalchemy import and_
# query.filter(and_(User.name == 'ed', User.fullname == 'Ed Jones'))

# # or send multiple expressions to .filter()
# query.filter(User.name == 'ed', User.fullname == 'Ed Jones')

# # or chain multiple filter()/filter_by() calls
# query.filter(User.name == 'ed').filter(User.fullname == 'Ed Jones')

# %%
# from sqlalchemy import or_
# query.filter(or_(User.name == 'ed', User.name == 'wendy'))

# %%
# query.filter(User.name.match('wendy'))

# %%
query = session.query(User).filter(User.name.like('%ed')).order_by(User.id)
query.all()
# Out:
# [<User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>]

# %%
query.first()
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>

# %%
user = query.one()
# Out:
# ---------------------------------------------------------------------------
# MultipleResultsFound                      Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 114 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000158vscode-remote?line=0'>1</a> user = query.one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2865, in Query.one(self)
#    2847 def one(self):
#    2848     """Return exactly one result or raise an exception.
#    2849
#    2850     Raises ``sqlalchemy.orm.exc.NoResultFound`` if the query selects
#    (...)
#    2863
#    2864     """
# -> 2865     return self._iter().one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1417, in ScalarResult.one(self)
#    1409 def one(self):
#    1410     """Return exactly one object or raise an exception.
#    1411
#    1412     Equivalent to :meth:`_result.Result.one` except that
#    (...)
#    1415
#    1416     """
# -> 1417     return self._only_one_row(
#    1418         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1419     )
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:614, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     612     if next_row is not _NO_ROW:
#     613         self._soft_close(hard=True)
# --> 614         raise exc.MultipleResultsFound(
#     615             "Multiple rows were found when exactly one was required"
#     616             if raise_for_none
#     617             else "Multiple rows were found when one or none "
#     618             "was required"
#     619         )
#     620 else:
#     621     next_row = _NO_ROW
#
# MultipleResultsFound: Multiple rows were found when exactly one was required

# %%
user = query.filter(User.id == 99).one()
# Out:
# ---------------------------------------------------------------------------
# NoResultFound                             Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 115 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000159vscode-remote?line=0'>1</a> user = query.filter(User.id == 99).one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2865, in Query.one(self)
#    2847 def one(self):
#    2848     """Return exactly one result or raise an exception.
#    2849
#    2850     Raises ``sqlalchemy.orm.exc.NoResultFound`` if the query selects
#    (...)
#    2863
#    2864     """
# -> 2865     return self._iter().one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1417, in ScalarResult.one(self)
#    1409 def one(self):
#    1410     """Return exactly one object or raise an exception.
#    1411
#    1412     Equivalent to :meth:`_result.Result.one` except that
#    (...)
#    1415
#    1416     """
# -> 1417     return self._only_one_row(
#    1418         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1419     )
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:562, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     560 if row is None:
#     561     if raise_for_none:
# --> 562         raise exc.NoResultFound(
#     563             "No row was found when one was required"
#     564         )
#     565     else:
#     566         return None
#
# NoResultFound: No row was found when one was required

# %%
query = session.query(User.id).filter(User.name == 'ed').\
   order_by(User.id)
query.scalar()
# Out:
# ---------------------------------------------------------------------------
# MultipleResultsFound                      Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 116 in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000161vscode-remote?line=0'>1</a> query = session.query(User.id).filter(User.name == 'ed').\
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000161vscode-remote?line=1'>2</a>    order_by(User.id)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000161vscode-remote?line=2'>3</a> query.scalar()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2888, in Query.scalar(self)
#    2886 # TODO: not sure why we can't use result.scalar() here
#    2887 try:
# -> 2888     ret = self.one()
#    2889     if not isinstance(ret, collections_abc.Sequence):
#    2890         return ret
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2865, in Query.one(self)
#    2847 def one(self):
#    2848     """Return exactly one result or raise an exception.
#    2849
#    2850     Raises ``sqlalchemy.orm.exc.NoResultFound`` if the query selects
#    (...)
#    2863
#    2864     """
# -> 2865     return self._iter().one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1200, in Result.one(self)
#    1173 def one(self):
#    1174     """Return exactly one row or raise an exception.
#    1175
#    1176     Raises :class:`.NoResultFound` if the result returns no
#    (...)
#    1198
#    1199     """
# -> 1200     return self._only_one_row(
#    1201         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1202     )
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:614, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     612     if next_row is not _NO_ROW:
#     613         self._soft_close(hard=True)
# --> 614         raise exc.MultipleResultsFound(
#     615             "Multiple rows were found when exactly one was required"
#     616             if raise_for_none
#     617             else "Multiple rows were found when one or none "
#     618             "was required"
#     619         )
#     620 else:
#     621     next_row = _NO_ROW
#
# MultipleResultsFound: Multiple rows were found when exactly one was required

# %%
from sqlalchemy import text
for user in session.query(User).\
            filter(text("id<224")).\
            order_by(text("id")).all():
    print(user.name)
# Out:
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred
# ed
# jake
# wendy
# mary
# fred

# %%
session.query(User).filter(text("id<:value and name=:name")).\
    params(value=224, name='fred').order_by(User.id).one()
# Out:
# ---------------------------------------------------------------------------
# MultipleResultsFound                      Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 118 in <cell line: 1>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000163vscode-remote?line=0'>1</a> session.query(User).filter(text("id<:value and name=:name")).\
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000163vscode-remote?line=1'>2</a>     params(value=224, name='fred').order_by(User.id).one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2865, in Query.one(self)
#    2847 def one(self):
#    2848     """Return exactly one result or raise an exception.
#    2849
#    2850     Raises ``sqlalchemy.orm.exc.NoResultFound`` if the query selects
#    (...)
#    2863
#    2864     """
# -> 2865     return self._iter().one()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:1417, in ScalarResult.one(self)
#    1409 def one(self):
#    1410     """Return exactly one object or raise an exception.
#    1411
#    1412     Equivalent to :meth:`_result.Result.one` except that
#    (...)
#    1415
#    1416     """
# -> 1417     return self._only_one_row(
#    1418         raise_for_second_row=True, raise_for_none=True, scalar=False
#    1419     )
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/engine/result.py:614, in ResultInternal._only_one_row(self, raise_for_second_row, raise_for_none, scalar)
#     612     if next_row is not _NO_ROW:
#     613         self._soft_close(hard=True)
# --> 614         raise exc.MultipleResultsFound(
#     615             "Multiple rows were found when exactly one was required"
#     616             if raise_for_none
#     617             else "Multiple rows were found when one or none "
#     618             "was required"
#     619         )
#     620 else:
#     621     next_row = _NO_ROW
#
# MultipleResultsFound: Multiple rows were found when exactly one was required

# %%
session.query(User).from_statement(
 text("SELECT * FROM users where name=:name")).params(name='ed').all()
# Out:
# [<User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>]

# %%
stmt = text("SELECT name, id, fullname, nickname "
            "FROM users where name=:name")
stmt = stmt.columns(User.name, User.id, User.fullname, User.nickname)
session.query(User).from_statement(stmt).params(name='ed').all()
# Out:
# [<User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>,
#  <User(name=ed, fullname=Ed Jones, nickname=eddie)>]

# %%
stmt = text("SELECT name, id FROM users where name=:name")
stmt = stmt.columns(User.name, User.id)
session.query(User.id, User.name).\
         from_statement(stmt).params(name='ed').all()
# Out:
# [(1, 'ed'), (7, 'ed'), (13, 'ed'), (19, 'ed')]

# %%
session.query(User).filter(User.name.like('%ed')).count()
# Out:
# 8

# %%
for user in session.query(User).all():
    print(user)
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>
# <User(name=ed, fullname=Ed Jones, nickname=eddie)>
# <User(name=jake, fullname=Jake Park, nickname=sorry)>
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)>
# <User(name=mary, fullname=Mary Contrary, nickname=mary)>
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)>

# %%
from sqlalchemy import func
session.query(func.count(User.name), User.name).group_by(User.name).all()
# Out:
# [(4, 'ed'), (4, 'jake'), (4, 'wendy'), (4, 'mary'), (4, 'fred')]

# %%
session.query(func.count('*')).select_from(User).scalar()
# Out:
# 20

# %%
session.query(func.count(User.id)).scalar()
# Out:
# 20

# %%
from sqlalchemy import ForeignKey
from sqlalchemy.orm import relationship

class Address(Base):
    __tablename__ = 'addresses'
    id = Column(Integer, primary_key=True)
    email_address = Column(String(50), nullable=False)
    user_id = Column(Integer, ForeignKey('users.id'))

    user = relationship('User', back_populates='addresses')

    def __repr__(self):
        return "<Address(email_addresses='{self.email_address}')>"

# %%
Address.__table__
# Out:
# Table('addresses', MetaData(), Column('id', Integer(), table=<addresses>, primary_key=True, nullable=False), Column('email_address', String(length=50), table=<addresses>, nullable=False), Column('user_id', Integer(), ForeignKey('users.id'), table=<addresses>), schema=None)

# %%
User.addresses = relationship(
    "Address", order_by=Address.id, back_populates="user")

# %%
Base.metadata.create_all(engine)

# %%
jack = User(name='jack', fullname='Jack Bean', nickname='gjffdd')
jack.addresses
# Out:
# []

# %%
jack.addresses = [
                Address(email_address='jack@google.com'),
                Address(email_address='j25@yahoo.com')]

# %%
jack.addresses[1]
# Out:
# <Address(email_addresses='{self.email_address}')>

# %%
jack.addresses[1].user
# Out:
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)>

# %%
session.add(jack)
session.commit()

# %%
jack = session.query(User).\
filter_by(name='jack').one()


jack
# Out:
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)>

# %%
jack.addresses
# Out:
# [<Address(email_addresses='{self.email_address}')>,
#  <Address(email_addresses='{self.email_address}')>]

# %%
for u, a in session.query(User, Address).\
                    filter(User.id==Address.user_id).\
                    filter(Address.email_address=='jack@google.com').\
                    all():
    print(u)
    print(a)
# Out:
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)>
# <Address(email_addresses='{self.email_address}')>

# %%
session.query(User).join(Address).\
        filter(Address.email_address=='jack@google.com').\
        all()
# Out:
# [<User(name=jack, fullname=Jack Bean, nickname=gjffdd)>]

# %%
# query.join(Address, User.id==Address.user_id)          # explicit condition
# query.join(User.addresses)                             # specify relationship from left to right
# query.join(Address, User.addresses)                    # same, with explicit target
# query.join(User.addresses.and_(Address.name != 'foo')) # use relationship + additional ON criteria
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 140 in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000191vscode-remote?line=1'>2</a> query.join(User.addresses)                             # specify relationship from left to right
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000191vscode-remote?line=2'>3</a> query.join(Address, User.addresses)                    # same, with explicit target
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000191vscode-remote?line=3'>4</a> query.join(User.addresses.and_(Address.name != 'foo'))
#
# AttributeError: type object 'Address' has no attribute 'name'

# %%
query.outerjoin(User.addresses)   # LEFT OUTER JOIN

# %%
query = session.query(User, Address).select_from(Address).join(User)

# %%
from sqlalchemy.orm import aliased
adalias1 = aliased(Address)
adalias2 = aliased(Address)
for username, email1, email2 in \
    session.query(User.name, adalias1.email_address, adalias2.email_address).\
    join(User.addresses.of_type(adalias1)).\
    join(User.addresses.of_type(adalias2)).\
    filter(adalias1.email_address=='jack@google.com').\
    filter(adalias2.email_address=='j25@yahoo.com'):
    print(username, email1, email2)
# Out:
# jack jack@google.com j25@yahoo.com

# %%
# equivalent to query.join(User.addresses.of_type(adalias1))
q = query.join(adalias1, User.addresses)

# %%
SELECT users.*, adr_count.address_count FROM users LEFT OUTER JOIN
    (SELECT user_id, count(*) AS address_count
        FROM addresses GROUP BY user_id) AS adr_count
    ON users.id=adr_count.user_id
# Out:
#   Input In [78]
#     SELECT users.*, adr_count.address_count FROM users LEFT OUTER JOIN
#            ^
# SyntaxError: invalid syntax

# %%
from sqlalchemy.sql import func
stmt = session.query(Address.user_id, func.count('*').\
        label('address_count')).\
        group_by(Address.user_id).subquery()

# %%
for u, count in session.query(User, stmt.c.address_count).\
    outerjoin(stmt, User.id==stmt.c.user_id).order_by(User.id):
    print(u, count)
# Out:
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> None
# <User(name=jake, fullname=Jake Park, nickname=sorry)> None
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> None
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> None
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> None
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> None
# <User(name=jake, fullname=Jake Park, nickname=sorry)> None
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> None
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> None
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> None
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> None
# <User(name=jake, fullname=Jake Park, nickname=sorry)> None
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> None
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> None
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> None
# <User(name=ed, fullname=Ed Jones, nickname=eddie)> None
# <User(name=jake, fullname=Jake Park, nickname=sorry)> None
# <User(name=wendy, fullname=Wendy Williams, nickname=windy)> None
# <User(name=mary, fullname=Mary Contrary, nickname=mary)> None
# <User(name=fred, fullname=Fred Flinstone, nickname=freddy)> None
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)> 2

# %%
stmt = session.query(Address).\
                filter(Address.email_address != 'j25@yahoo.com').\
                subquery()
addr_alias = aliased(Address, stmt)
for user, address in session.query(User, addr_alias).\
        join(addr_alias, User.addresses):
    print(user)
    print(address)
# Out:
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)>
# <Address(email_addresses='{self.email_address}')>

# %%
from sqlalchemy.sql import exists
stmt = exists().where(Address.user_id==User.id)
for name, in session.query(User.name).filter(stmt):
    print(name)
# Out:
# jack

# %%
for name, in session.query(User.name).\
        filter(User.addresses.any()):
    print(name)
# Out:
# jack

# %%
for name, in session.query(User.name).\
    filter(User.addresses.any(Address.email_address.like('%google%'))):
    print(name)
# Out:
# jack

# %%
session.query(Address).\
        filter(~Address.user.has(User.name=='jack')).all()
# Out:
# []

# %%
# query.filter(Address.user == someuser)
# query.filter(Address.user != someuser)
# query.filter(Address.user == None)
# query.filter(User.addresses.contains(someaddress))
# query.filter(User.addresses.any(Address.email_address == 'bar'))

# # also takes keyword arguments:
# query.filter(User.addresses.any(email_address='bar'))
# query.filter(Address.user.has(name='ed'))
# session.query(Address).with_parent(someuser, 'addresses')

# %%
from sqlalchemy.orm import selectinload
jack = session.query(User).\
                options(selectinload(User.addresses)).\
                filter_by(name='jack').one()


jack

jack.addresses
# Out:
# [<Address(email_addresses='{self.email_address}')>,
#  <Address(email_addresses='{self.email_address}')>]

# %%
from sqlalchemy.orm import joinedload

jack = session.query(User).\
                       options(joinedload(User.addresses)).\
                       filter_by(name='jack').one()


jack

jack.addresses
# Out:
# [<Address(email_addresses='{self.email_address}')>,
#  <Address(email_addresses='{self.email_address}')>]

# %%
from sqlalchemy.orm import contains_eager
jacks_addresses = session.query(Address).\
                            join(Address.user).\
                            filter(User.name=='jack').\
                            options(contains_eager(Address.user)).\
                            all()


jacks_addresses

jacks_addresses[0].user
# Out:
# <User(name=jack, fullname=Jack Bean, nickname=gjffdd)>

# %%
session.delete(jack)
session.query(User).filter_by(name='jack').count()
# Out:
# 0

# %%
session.query(Address).filter(
    Address.email_address.in_(['jack@google.com', 'j25@yahoo.com'])
 ).count()
# Out:
# 2

# %%
session.close()

# %%
Base = declarative_base()

# %%
class User(Base):
    __tablename__ = 'users'
    id = Column(Integer, primary_key=True)
    name = Column(String)
    fullname = Column(String)
    nickname = Column(String)
    addresses = relationship("Address", back_populates='user',
                    cascade="all, delete, delete-orphan")
    def __repr__(self):
       return "<User(name='%s', fullname='%s', nickname='%s')>" % (
                               self.name, self.fullname, self.nickname)

# %%
class Address(Base):
    __tablename__ = 'addresses'
    id = Column(Integer, primary_key=True)
    email_address = Column(String, nullable=False)
    user_id = Column(Integer, ForeignKey('users.id'))
    user = relationship("User", back_populates="addresses")
    def __repr__(self):
        return "<Address(email_address='%s')>" % self.email_address

# %%
jack = session.get(User, 5)



del jack.addresses[1]



session.query(Address).filter(
    Address.email_address.in_(['jack@google.com', 'j25@yahoo.com'])
).count()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/jake/codes/mysql-sqlalchemy/db.ipynb Cell 163 in <cell line: 5>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000217vscode-remote?line=0'>1</a> jack = session.get(User, 5)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000217vscode-remote?line=4'>5</a> del jack.addresses[1]
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000217vscode-remote?line=8'>9</a> session.query(Address).filter(
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000217vscode-remote?line=9'>10</a>     Address.email_address.in_(['jack@google.com', 'j25@yahoo.com'])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jake/codes/mysql-sqlalchemy/db.ipynb#ch0000217vscode-remote?line=10'>11</a> ).count()
#
# File ~/anaconda3/envs/flask/lib/python3.10/site-packages/sqlalchemy/orm/collections.py:1239, in _list_decorators.<locals>.__delitem__.<locals>.__delitem__(self, index)
#    1237 def __delitem__(self, index):
#    1238     if not isinstance(index, slice):
# -> 1239         item = self[index]
#    1240         __del(self, item)
#    1241         fn(self, index)
#
# IndexError: list index out of range

# %%
session.delete(jack)

session.query(User).filter_by(name='jack').count()



session.query(Address).filter(
   Address.email_address.in_(['jack@google.com', 'j25@yahoo.com'])
).count()
# Out:
# 2

# %%
from sqlalchemy import Table, Text
# association table
post_keywords = Table('post_keywords', Base.metadata,
    Column('post_id', ForeignKey('posts.id'), primary_key=True),
    Column('keyword_id', ForeignKey('keywords.id'), primary_key=True)
)

# %%
class BlogPost(Base):
    __tablename__ = 'posts'
    id = Column(Integer, primary_key=True)
    user_id = Column(Integer, ForeignKey('users.id'))
    headline = Column(String(255), nullable=False)
    body = Column(Text)
    # many to many BlogPost<->Keyword
    keywords = relationship('Keyword',
                            secondary=post_keywords,
                            back_populates='posts')
    def __init__(self, headline, body, author):
        self.author = author
        self.headline = headline
        self.body = body
    def __repr__(self):
        return "BlogPost(%r, %r, %r)" % (self.headline, self.body, self.author)


class Keyword(Base):
    __tablename__ = 'keywords'
    id = Column(Integer, primary_key=True)
    keyword = Column(String(50), nullable=False, unique=True)
    posts = relationship('BlogPost',
                         secondary=post_keywords,
                         back_populates='keywords')
    def __init__(self, keyword):
        self.keyword = keyword

# %%
BlogPost.author = relationship(User, back_populates="posts")
User.posts = relationship(BlogPost, back_populates="author", lazy="dynamic")

# %%
Base.metadata.create_all(engine)

# %%
wendy = session.query(User).\
                filter_by(name='wendy').\
                one()


post = BlogPost("Wendy's Blog Post", "This is a test", wendy)
session.add(post)

# %%
post.keywords.append(Keyword('wendy'))
post.keywords.append(Keyword('firstpost'))

# %%
session.query(BlogPost).\
            filter(BlogPost.keywords.any(keyword='firstpost')).\
            all()

# %%
session.query(BlogPost).\
            filter(BlogPost.author==wendy).\
            filter(BlogPost.keywords.any(keyword='firstpost')).\
            all()

# %%
wendy.posts.\
        filter(BlogPost.keywords.any(keyword='firstpost')).\
        all()
